# %%
2 - 8
# Out:
# -6

# %% [markdown]
# I love my country Somalia

# %% [markdown]
# These are the countries I will like to visit in the nearest future
#
#
# - America
#
# - Nigeria
#
# - Rwanda

# %% [markdown]
# These are the countries I will like to visit in the nearest future
#
#
# 1. America
#
# 2. Nigeria
#
# 3. Rwanda
