# %% [markdown]
# ## Dictionary
#
#
# A **dictionary** is an ordered collection of **key–value pairs**. In other words, it uses two elements: a *key* and a *value*. Dictionaries are commonly used when working with large amounts of data, as each value is accessed through its unique key.
#
#
# You can create a dictionary by defining key–value pairs inside curly braces `{}`, with each pair separated by a comma.
#
#
# # Example 1

# %%
my_dictionary = {"Key 1": "Value 1", "Key 2": "Value 2",  "Key 3": "Value 3", "Key 4": "Value 4", "Key 4": "Value 4"}

# %%
my_dictionary
# Out:
# {'Key 1': 'Value 1',
#  'Key 2': 'Value 2',
#  'Key 3': 'Value 3',
#  'Key 4': 'Value 4'}

# %%
type(my_dictionary)
# Out:
# dict

# %% [markdown]
# # Example 2

# %%
# Life expectancy is the average number of year a person is expected to live based on the year of its birth

# life expectancy in the year 2020

life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, "Tanzania": 64, "Somalia": 54}

# %%
life_expectancy
# Out:
# {'Nigeria': 60,
#  'Kenya': 69,
#  'Uganda': 68,
#  'Ethiopia': 68,
#  'Sudan': 67,
#  'Rwanda': 65,
#  'Tanzania': 64,
#  'Somalia': 54}

# %%
type(life_expectancy)
# Out:
# dict

# %% [markdown]
# # Example 3

# %%
# Some countries in the given Africa regions

africa_regions = {"East Africa": ["Ethiopia", "Kenya", "Rwanda", "Somalia", "South Sudan", "Uganda", "Burundi"],
                    "North Africa": ["Algeria", "Egypt", "Libya", "Morocco", "Sudan", "Tunisia"],
                    "West Africa": ["Nigeria", "Ghana" "Senegal", "Benin", "Liberia", "Mali", "Niger"],
                      "Central Africa": ["Angola", "Cameroon", "Chad", "Congo", "DRC", "Gabon"],
                      "Southern Africa": ["Botswana", "Eswatini", "Lesotho", "Namibia", "RÈunion", "South Africa"]}

# %%
print(africa_regions)
# Out:
# {'East Africa': ['Ethiopia', 'Kenya', 'Rwanda', 'Somalia', 'South Sudan', 'Uganda', 'Burundi'], 'North Africa': ['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'], 'West Africa': ['Nigeria', 'GhanaSenegal', 'Benin', 'Liberia', 'Mali', 'Niger'], 'Central Africa': ['Angola', 'Cameroon', 'Chad', 'Congo', 'DRC', 'Gabon'], 'Southern Africa': ['Botswana', 'Eswatini', 'Lesotho', 'Namibia', 'RÈunion', 'South Africa']}

# %%
africa_regions
# Out:
# {'East Africa': ['Ethiopia',
#   'Kenya',
#   'Rwanda',
#   'Somalia',
#   'South Sudan',
#   'Uganda',
#   'Burundi'],
#  'North Africa': ['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'],
#  'West Africa': ['Nigeria',
#   'GhanaSenegal',
#   'Benin',
#   'Liberia',
#   'Mali',
#   'Niger'],
#  'Central Africa': ['Angola', 'Cameroon', 'Chad', 'Congo', 'DRC', 'Gabon'],
#  'Southern Africa': ['Botswana',
#   'Eswatini',
#   'Lesotho',
#   'Namibia',
#   'RÈunion',
#   'South Africa']}

# %%
type(africa_regions)
# Out:
# dict

# %% [markdown]
# ## Dictionary Length
#
# To determine how many items a dictionary has, use the `len()` function.
#
# ## Example 1

# %%
life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, 
                   "Tanzania": 64, "Somalia": 54}

len(life_expectancy)
# Out:
# 8

# %% [markdown]
# ## Example 2

# %%
africa_regions = {"East Africa": ["Ethiopia", "Kenya", "Rwanda", "Somalia", "South Sudan", "Uganda", "Burundi"],
                    "North Africa": ["Algeria", "Egypt", "Libya", "Morocco", "Sudan", "Tunisia"],
                    "West Africa": ["Nigeria", "Ghana" "Senegal", "Benin", "Liberia", "Mali", "Niger"],
                      "Central Africa": ["Angola", "Cameroon", "Chad", "Congo", "DRC", "Gabon"],
                      "Southern Africa": ["Botswana", "Eswatini", "Lesotho", "Namibia", "RÈunion", "South Africa"]}

len(africa_regions)
# Out:
# 5

# %% [markdown]
# # Accessing dictionary items

# %% [markdown]
# Dictionary items are presented in `key : value` pairs, and can be referred to by using the key name. To access a specific value in the dictionary data set, you need to index the right `key`. Dictionaries in Python are mutable and the elements in a dictionary can be added, removed, modified, and changed accordingly.

# %% [markdown]
# You can access the items of a dictionary by referring to its key name, inside square brackets. For example, consider life expectancy dictionay:

# %%
life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, "Tanzania": 64, "Somalia": 54}

# %% [markdown]
# To access the value in the key Nigeria, we use:

# %%
life_expectancy["Nigeria"]
# Out:
# 60

# %% [markdown]
# Also, for Ethiopia, we use:

# %%
life_expectancy["Ethiopia"]
# Out:
# 68

# %%
life_expectancy["Rwanda"]
# Out:
# 65

# %% [markdown]
# You can not access items in a dictionary by index

# %%
life_expectancy[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-11499ef467a4> in <module>
# ----> 1 life_expectancy[0]
#
# KeyError: 0

# %% [markdown]
# # Dictionary Methods
#
# Methods in a dictionary are as follows:
#
#
# - `.keys()`
#
# - `.values()`
#
# - `.items()`
#
# - `.updates()`

# %% [markdown]
# ## .keys() method
#
# The `.keys()` method will return a list of all the keys in the dictionary.

# %% [markdown]
# ## Example 1

# %%
life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, 
                   "Tanzania": 64, "Somalia": 54}

# %%
life_expectancy.keys()
# Out:
# dict_keys(['Nigeria', 'Kenya', 'Uganda', 'Ethiopia', 'Sudan', 'Rwanda', 'Tanzania', 'Somalia'])

# %% [markdown]
# ## Example 2

# %%
africa_regions = {"East Africa": ["Ethiopia", "Kenya", "Rwanda", "Somalia", "South Sudan", "Uganda", "Burundi"],
                    "North Africa": ["Algeria", "Egypt", "Libya", "Morocco", "Sudan", "Tunisia"],
                    "West Africa": ["Nigeria", "Ghana" "Senegal", "Benin", "Liberia", "Mali", "Niger"],
                      "Central Africa": ["Angola", "Cameroon", "Chad", "Congo", "DRC", "Gabon"],
                      "Southern Africa": ["Botswana", "Eswatini", "Lesotho", "Namibia", "RÈunion", "South Africa"]}

# %%
africa_regions.keys()
# Out:
# dict_keys(['East Africa', 'North Africa', 'West Africa', 'Central Africa', 'Southern Africa'])

# %% [markdown]
# ## .values() method
#
# The `.values()` method will return a list of all the values in the dictionary.

# %% [markdown]
# ## Example 1

# %%
life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, 
                   "Tanzania": 64, "Somalia": 54}

# %%
life_expectancy.values()
# Out:
# dict_values([60, 69, 68, 68, 67, 65, 64, 54])

# %% [markdown]
# ## Example 2

# %%
africa_regions = {"East Africa": ["Ethiopia", "Kenya", "Rwanda", "Somalia", "South Sudan", "Uganda", "Burundi"],
                    "North Africa": ["Algeria", "Egypt", "Libya", "Morocco", "Sudan", "Tunisia"],
                    "West Africa": ["Nigeria", "Ghana" "Senegal", "Benin", "Liberia", "Mali", "Niger"],
                      "Central Africa": ["Angola", "Cameroon", "Chad", "Congo", "DRC", "Gabon"],
                      "Southern Africa": ["Botswana", "Eswatini", "Lesotho", "Namibia", "RÈunion", "South Africa"]}

# %%
africa_regions.values()
# Out:
# dict_values([['Ethiopia', 'Kenya', 'Rwanda', 'Somalia', 'South Sudan', 'Uganda', 'Burundi'], ['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'], ['Nigeria', 'GhanaSenegal', 'Benin', 'Liberia', 'Mali', 'Niger'], ['Angola', 'Cameroon', 'Chad', 'Congo', 'DRC', 'Gabon'], ['Botswana', 'Eswatini', 'Lesotho', 'Namibia', 'RÈunion', 'South Africa']])

# %% [markdown]
# # .items() method
#
# The `items()` method will return each item in a dictionary, as tuples in a list.

# %% [markdown]
# ## Example 1

# %%
life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, 
                   "Tanzania": 64, "Somalia": 54}

# %%
life_expectancy.items()
# Out:
# dict_items([('Nigeria', 60), ('Kenya', 69), ('Uganda', 68), ('Ethiopia', 68), ('Sudan', 67), ('Rwanda', 65), ('Tanzania', 64), ('Somalia', 54)])

# %% [markdown]
# ## Example 2

# %%
africa_regions = {"East Africa": ["Ethiopia", "Kenya", "Rwanda", "Somalia", "South Sudan", "Uganda", "Burundi"],
                "North Africa": ["Algeria", "Egypt", "Libya", "Morocco", "Sudan", "Tunisia"],
                "West Africa": ["Nigeria", "Ghana" "Senegal", "Benin", "Liberia", "Mali", "Niger"],
                "Central Africa": ["Angola", "Cameroon", "Chad", "Congo", "DRC", "Gabon"],
                "Southern Africa": ["Botswana", "Eswatini", "Lesotho", "Namibia", "RÈunion", "South Africa"]}

# %%
africa_regions.items()
# Out:
# dict_items([('East Africa', ['Ethiopia', 'Kenya', 'Rwanda', 'Somalia', 'South Sudan', 'Uganda', 'Burundi']), ('North Africa', ['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia']), ('West Africa', ['Nigeria', 'GhanaSenegal', 'Benin', 'Liberia', 'Mali', 'Niger']), ('Central Africa', ['Angola', 'Cameroon', 'Chad', 'Congo', 'DRC', 'Gabon']), ('Southern Africa', ['Botswana', 'Eswatini', 'Lesotho', 'Namibia', 'RÈunion', 'South Africa'])])

# %% [markdown]
# # Update Dictionary
#
# The `.update()` method will update the dictionary with the items from the given argument. The argument must be an object with key:value pairs.

# %%
life_expectancy = {"Nigeria": 60, "Kenya": 69, "Uganda": 68, "Ethiopia": 68, "Sudan": 67, "Rwanda": 65, 
                   "Tanzania": 64, "Somalia": 54}

# %% [markdown]
# You were given the life expectancy of Burundi as $70$. You can add that to the existing dictionary by using:

# %%
life_expectancy.update({"Burundi":70})

# %%
life_expectancy
# Out:
# {'Nigeria': 60,
#  'Kenya': 69,
#  'Uganda': 68,
#  'Ethiopia': 68,
#  'Sudan': 67,
#  'Rwanda': 65,
#  'Tanzania': 64,
#  'Somalia': 54,
#  'Burundi': 70}

# %% [markdown]
# We can also use a new index key and value to add a new item

# %%
life_expectancy["Eritrea"] = 66

# %%
life_expectancy
# Out:
# {'Nigeria': 60,
#  'Kenya': 69,
#  'Uganda': 68,
#  'Ethiopia': 68,
#  'Sudan': 67,
#  'Rwanda': 65,
#  'Tanzania': 64,
#  'Somalia': 54,
#  'Burundi': 70,
#  'Eritrea': 66}

# %% [markdown]
# # Removing Items in a dictionary
#
# The `del` keyword removes the item with the specified key name.
#
# # Example 1
#
# For example, to delete information about Eritrea in the life expectancy dictionary we use:

# %%
del life_expectancy["Eritrea"]

# %%
life_expectancy
# Out:
# {'Nigeria': 60,
#  'Kenya': 69,
#  'Uganda': 68,
#  'Ethiopia': 68,
#  'Sudan': 67,
#  'Rwanda': 65,
#  'Tanzania': 64,
#  'Somalia': 54,
#  'Burundi': 70}

# %%
del life_expectancy["Nigeria"]

# %%
life_expectancy
# Out:
# {'Kenya': 69,
#  'Uganda': 68,
#  'Ethiopia': 68,
#  'Sudan': 67,
#  'Rwanda': 65,
#  'Tanzania': 64,
#  'Somalia': 54,
#  'Burundi': 70}

# %% [markdown]
# # Example 2
# To delete information about Burundi, we use:

# %%
del life_expectancy["Burundi"]

# %%
life_expectancy
# Out:
# {'Kenya': 69,
#  'Uganda': 68,
#  'Ethiopia': 68,
#  'Sudan': 67,
#  'Rwanda': 65,
#  'Tanzania': 64,
#  'Somalia': 54}
