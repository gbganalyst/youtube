# %% [markdown]
# # Data Types in Python

# %% [markdown]
# Python can tell you the data type by using `type()` function. Python refers to integers as `int`, floats as `float`, character or text as `str` and boolean as `bool`.
#
# ## Integer data type
#
# Integers are numerical (number) values that are positive or negative whole numbers without decimals
#
# ## Examples

# %%
type(1)
# Out:
# int

# %%
type(19)
# Out:
# int

# %%
type(-71)
# Out:
# int

# %% [markdown]
# ## Float data type
#
# Float (floating point) numbers are numbers with a decimal point.
#
# ## Example

# %%
type(12.6)
# Out:
# float

# %%
type(56.9)
# Out:
# float

# %%
type(-71.2)
# Out:
# float

# %% [markdown]
# ## String data type
#
# Characters or texts are known as string in Python. A string object must be inside a single or double quotation. Otherwise, Python will throw an error.
#
# ## Examples

# %%
type("Hello Python")
# Out:
# str

# %%
type("Hello Python")
# Out:
# str

# %%
type("I am a Nigerian")
# Out:
# str

# %%
type("I love to come to Nigeria")
# Out:
# str

# %%
type("I love Python programming")
# Out:
# str

# %% [markdown]
# # Tips
#
# It is common to see most Python users using the function `print()` in their line of codes. For now, all you need to know is that it instructs python on what to print.

# %%
print("Hello, I am from Nigeria and I can speak Yoruba")
# Out:
# Hello, I am from Ethiopia and I can speak Amharic

# %%
"Hello, I am from Nigeria and I can speak Yoruba"
# Out:
# 'Hello, I am from Nigeria and I can speak Yoruba'

# %% [markdown]
# ?print

# %% [markdown]
# ## Boolean data type

# %% [markdown]
# A boolean or bool is an object in python that can take two values i.e. `True` or `False`.

# %%
# To check the data type

type(True)
# Out:
# bool

# %%
# To check the data type

type(False)
# Out:
# bool

# %%
type(5>2)
# Out:
# bool

# %%
5>2
# Out:
# True

# %%
2<5
# Out:
# True

# %%
5<2
# Out:
# False

# %%
type(5<2)
# Out:
# bool
